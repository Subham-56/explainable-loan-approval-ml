# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\KIIT0001\OneDrive\Desktop\Project\05_loan_approval\Data\cleaned_loan_data.csv")

# %%
df["TotalIncome"] = df["ApplicantIncome"] + df["CoapplicantIncome"]

# %%
df["Income_Loan_Ratio"] = df["TotalIncome"] / df["LoanAmount"]

# %%
df["LoanAmount"] = df["LoanAmount"].fillna(df["LoanAmount"].median())

# handle missing values

# %%
X = df.drop(columns=["Loan_Status", "loan_approved"])
y = df["loan_approved"]

# %%
df.to_csv(r"C:\Users\KIIT0001\OneDrive\Desktop\Project\05_loan_approval\Data\featured_loan_data.csv", index=False)

# %%
df[[
    "ApplicantIncome",
    "CoapplicantIncome",
    "TotalIncome",
    "LoanAmount",
    "Income_Loan_Ratio",
    "loan_approved"
]].head()
# Out:
#    ApplicantIncome  CoapplicantIncome  TotalIncome  LoanAmount  \
# 0             5849                0.0       5849.0       128.0
# 1             4583             1508.0       6091.0       128.0
# 2             3000                0.0       3000.0        66.0
# 3             2583             2358.0       4941.0       120.0
# 4             6000                0.0       6000.0       141.0
#
#    Income_Loan_Ratio  loan_approved
# 0                NaN              1
# 1          47.585938              0
# 2          45.454545              1
# 3          41.175000              1
# 4          42.553191              1
